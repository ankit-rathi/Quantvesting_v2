# %% [markdown]
# <a href="https://colab.research.google.com/github/ankit-rathi/Quantvesting_v2/blob/main/agenticAI/myQuantvesting_Agent_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-genai

# %%
import os
import google.generativeai as genai # Reverted to google.generativeai to access list_models, despite FutureWarning

os.environ["GOOGLE_API_KEY"] = "AIzaSyDkSneR7VQEzsNirCKlNwxQmJxbXOQMQCQ"
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

for m in genai.list_models():
    print(m.name, "→", m.supported_generation_methods)
# Out:
# models/gemini-2.5-flash → ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.5-pro → ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.0-flash → ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.0-flash-001 → ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.0-flash-lite-001 → ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.0-flash-lite → ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.5-flash-preview-tts → ['countTokens', 'generateContent']
# models/gemini-2.5-pro-preview-tts → ['countTokens', 'generateContent', 'batchGenerateContent']
# models/gemma-3-1b-it → ['generateContent', 'countTokens']
# models/gemma-3-4b-it → ['generateContent', 'countTokens']
# ...

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

def ask_llm(prompt):
    response = model.generate_content(prompt)
    return response.text

# %%
def gather_info(company):
    prompt = f"""
    Provide a structured overview of {company}:
    - Business model
    - Revenue drivers
    - Risks
    - Industry trends
    """
    return ask_llm(prompt)

# %%
def analyze_pros_cons(info):
    prompt = f"""
    Based on the following information:

    {info}

    List:
    Pros:
    Cons:
    """
    return ask_llm(prompt)

# %%
def evaluate_investment(pros_cons):
    prompt = f"""
    Based on the following analysis:

    {pros_cons}

    Provide:
    - Investment thesis
    - Risks
    - Final recommendation (Buy / Avoid / Watch)
    - Confidence level (Low/Medium/High)
    """
    return ask_llm(prompt)

# %%
def decision_agent(company):
    print("Gathering info...")
    info = gather_info(company)

    print("Analyzing pros/cons...")
    pros_cons = analyze_pros_cons(info)

    print("Evaluating...")
    decision = evaluate_investment(pros_cons)

    return decision

# %%
result = decision_agent("TCS")
print(result)
# Out:
# Gathering info...
# Analyzing pros/cons...
# Evaluating...
# Based on the provided analysis of Pros and Cons for Tata Consultancy Services (TCS):
#
# ### Investment Thesis
#
# TCS is a strong investment given its position as a global leader in IT services, directly benefiting from the secular trend of enterprise digital transformation. Its comprehensive service portfolio, deep industry expertise across critical verticals (BFSI, Retail, Manufacturing, Life Sciences & Healthcare), and focus on long-term, high-value client relationships provide stable, recurring revenue. The company's continuous investment in emerging technologies (Cloud, AI/ML, Cybersecurity, Generative AI) and effective Global Network Delivery Model (GNDM) ensures it remains at the forefront of innovation, capturing an increasing share of growing corporate IT budgets through a consulting-led approach. This proactive adaptation and strategic client focus position TCS for sustained growth despite market challenges.
#
# ...

# %%
def refine_decision(company):
    decision = decision_agent(company)

    review_prompt = f"""
    Critically review this investment decision:

    {decision}

    Identify flaws, missing risks, and biases.
    """

    review = ask_llm(review_prompt)

    return decision, review

# %%
decision, review = refine_decision("TCS")

print("Decision:\n", decision)
print("\nReview:\n", review)
# Out:
# Gathering info...
# Analyzing pros/cons...
# Evaluating...
# Decision:
#  Based on the provided analysis:
#
# ## Investment Thesis
#
# TCS presents a compelling investment opportunity as a global leader in IT services, strategically positioned to capitalize on the secular growth trends in digital transformation, cloud adoption, artificial intelligence (AI), and cybersecurity. Its comprehensive and diversified service portfolio, strong client focus with long-term partnerships, and cost-efficient global delivery model provide a stable foundation for sustained revenue growth and profitability. The company's active investment in R&D, agile methodologies, and strategic alignment with high-growth technologies ensure its competitive edge and adaptability in a rapidly evolving technological landscape. Diversified geographic and industry presence further mitigates specific market downturn risks, making TCS a resilient player poised for continued value creation.
#
# ## Risks
#
# ...
